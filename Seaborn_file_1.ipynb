# %% [markdown]
# <h1> Visualization

# %% [markdown]
# ## Seaborn:
# Seaborn is open source code Python library. In the world of analytics the best way to get insights is by visualizing the data

# %% [markdown]
# Seaborn resolve the two major problem of Matplotlib:
# 1. Deafult matplotlib parameter
# 2. Working with dataframe
# ##### If you know matplotlib. you are in the half way of seaborn.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Some times during ploting data. output came with warnings to ignore warnings we import 'warnings'

# %%
import warnings
warnings.filterwarnings('ignore',category=FutureWarning)

# %% [markdown]
# Load data

# %%
df = pd.read_csv(r"D:\HP\IBM_(Machine Learning)\Excel_file (IBM) data\iris_data.csv")
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# #### Histogram:
# ##### Histograms represent the data distribution through bins
# distplot(df['numerical_column'],kde=, hist=)

# %%
sns.distplot(df['petal_length'])
plt.show()

# %%
sns.distplot(df['petal_length'],kde=False)
plt.show()

# %%
sns.distplot(df['petal_length'],hist=False)
plt.show()

# %% [markdown]
# #### Scatter plot: (Join_plot)
# ##### It show the relationship between the two variable's
# joinplot(x ='numercal_cloumn_name',y ='numercal_cloumn_name',data=)

# %%
sns.jointplot(x ='sepal_length',y = 'petal_length',data=df)
plt.show()

# %%
sns.jointplot(x ='sepal_length',y = 'petal_length',data=df,hue='species')
plt.show()

# %% [markdown]
# #### Multiple plot:
# ##### It show the realtionship of all columns with each other
# pairplot(data,hue ='categorical_column,diag_kind=, kind=, palette=)

# %%
sns.pairplot(df,hue="species",diag_kind='kde',kind='scatter',palette='husl')
plt.show()

# %% [markdown]
# #### Strip_plot
# ##### It is used when one of the variable study under the categorical
# stripplot(x ='categorical_column',y ="numerical_column",data=)

# %%
sns.stripplot(x ='species',y ="sepal_length",data=df,jitter=False)
plt.show()

# %%
sns.stripplot(x ='species',y ="sepal_length",data=df)
plt.show()

# %% [markdown]
# #### Swarm_plot:
# ##### It repersent the postion of each point under a categorica
# swarmplot(x ='categorical_column',y ="numercal_column",data=)

# %%
sns.swarmplot(x ='species',y ="sepal_length",data=df)
plt.show()

# %% [markdown]
# #### Box_plot:
# ##### Boxplot is a convenient way to visualize the distribution of data through their quartiles.
# boxplot(x ='categorical_column',y ="numercal_column",data=)

# %%
sns.boxplot(x ='species',y ="sepal_length",data=df)
plt.show()

# %%
sns.boxplot(data=df)
plt.show()

# %% [markdown]
# #### Violin_plot:
# ##### these plots are easier to analyze and understand the distribution of the data.
# violinplot(x ='categorical_column',y ="numercal_column",data=)

# %%
sns.violinplot(x='species',y='petal_length',data=df)
# Out:
# <AxesSubplot:xlabel='species', ylabel='petal_length'>

# %% [markdown]
# #### Bar_plot:
# ##### It shows the relation between a categorical variable and a continuous variable
# barplot(x ='categorical_column',y ="numercal_column",data=)

# %%
sns.barplot(x='species',y='petal_length',data=df)
plt.show()

# %% [markdown]
# #### Count_plot:
# ##### It repersent the count_values under a categorcal column
# countplot(x='categorcal_column',data= ,palette= )

# %%
sns.countplot(x='species',data=df,palette="Blues")
plt.show()

# %% [markdown]
# #### Point_plot:
# ##### Point plots serve same as bar plots but in a different style.
# pointplot(x='categorcal_column', y = 'numerical_column',data=)

# %%
sns.pointplot(x ='species',y='sepal_length',data=df)
plt.show()

# %% [markdown]
# #### Heat_plot:
# ##### It repersent the corealtion of colums
# heatmap(data.corr())

# %%
sns.heatmap(df.corr())
plt.show()

# %% [markdown]
# ## Thank you
